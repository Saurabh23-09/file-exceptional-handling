# %% [markdown]
# # FILE EXCEPTIONAL HANDLING

# %% [markdown]
# QUES 1 - What is the difference between interpreted and compiled languages?
# <!-- ANS 1  -The difference between interpreted and compiled languages lies in how their code is translated into machine-executable instructions:
#
# 🔧 Compiled Languages
# Process: Source code is translated all at once into machine code by a compiler before the program is run.
#
# Output: A standalone executable file.
#
# Speed: Generally faster at runtime, since the translation is done beforehand.
#
# Examples: C, C++, Rust, Go
#
# Pros:
#
# Faster performance
#
# No need for the compiler at runtime
#
# Often better optimization by the compiler
#
# Cons:
#
# Longer build times
#
# Less flexibility for dynamic execution or quick testing
#
# 🔍 Interpreted Languages
# Process: Source code is translated line-by-line (or block-by-block) at runtime by an interpreter.
#
# Output: No standalone executable; the interpreter must be present during execution.
#
# Speed: Generally slower due to real-time translation.
#
# Examples: Python, Ruby, JavaScript, PHP
#
# Pros:
#
# Easier to test and debug (you can run code immediately)
#
# More portable (if the interpreter is available)
#
# Cons:
#
# Slower execution
#
# Dependent on the interpreter being installed -->

# %% [markdown]
# QUES 2 - What is exception handling in Python
# <!-- ANS 2 - Exception handling in Python is a way to gracefully handle errors or unexpected events that occur during the execution of a program, so that the program doesn’t crash abruptly.
#
# 🧠 Why Use Exception Handling?
# Instead of terminating the program when an error occurs (like dividing by zero or trying to open a missing file), you can catch the error and decide what to do — like showing a message, using a fallback, or logging the error.
#
#  -->

# %% [markdown]
# QUES 3 -  What is the purpose of the finally block in exception handling?
# <!-- ANS 3 - The finally block in Python's exception handling is used to define code that should always run, regardless of whether an exception was raised or not.
#
# 🎯 Purpose of the finally Block
# Cleanup actions (e.g., closing files, releasing resources, disconnecting from a database)
#
# Ensures that critical code executes no matter what
#
# Runs after the try and except blocks
#
# ✅ Execution Guarantee
# The finally block always runs:
#
# If an exception occurs ✔️
#
# If no exception occurs ✔️
#
# Even if there’s a return in the try or except block ✔️ -->

# %% [markdown]
# QUES 4 -  What is logging in Python ?
# <!-- ANS 4 - In Python, logging is a way to track events that happen while your program runs. It's especially useful for:
#
# Debugging
#
# Monitoring applications in production
#
# Keeping records of events, errors, or warnings
#
# 🎯 Purpose of Logging
# Logging helps you understand the flow and behavior of a program without using print statements, and it's more flexible and powerful. -->

# %% [markdown]
# QUES 5 -  What is the significance of the __del__ method in Python ?
# <!-- ANS  5 - The __del__ method in Python is a special method called a destructor. It's triggered when an object is about to be destroyed, typically when it is garbage collected (i.e., when there are no more references to it).
#
# 🎯 Purpose of __del__
# To perform cleanup tasks before an object is removed from memory.
#
# Common use cases: closing files, releasing network connections, or freeing up system resources.
#
#  -->

# %% [markdown]
# QUES 6 - What is the difference between import and from ... import in Pytho?
# <!-- ANS 6 - In Python, import and from ... import are both used to bring in external modules or parts of them, but they work differently in how they load and access content.
# 1. import Statement
# What it does: Imports the entire math module.
#
# How you use it: You must prefix names with the module name.
#
# python
# Copy
# Edit
#
# 2. from ... import Statement
# What it does: Imports only the specified part (e.g. sqrt) from the module.
#
# How you use it: You can use it directly, without the module prefix.
#
# python
# Copy
# Edit
#  -->

# %% [markdown]
# QUES 7 -  How can you handle multiple exceptions in Python?
# <!-- ANS 7 In Python, you can handle multiple exceptions using several techniques depending on how you want to respond to different errors. Here's how:
#
# ✅ 1. Catch Multiple Exceptions in One except Block
# Use a tuple to catch several exceptions with the same handling logic:
# ✅ 2. Use Multiple except Blocks
# Handle different exceptions differently:
# ✅ 3. Catch All Exceptions (Use with Caution)
# This catches any exception.
#
# It's useful for logging or fallback logic but can hide bugs if overused -->

# %% [markdown]
# QUES  8 - What is the purpose of the with statement when handling files in Python ?
# <!-- ANS 8 - The with statement in Python is used for resource management, especially when handling files. It ensures that resources like files are automatically closed after their use, even if an error occurs.
#
# 🎯 Purpose of with When Handling Files
# Automatically opens and closes the file
#
# Prevents resource leaks
#
# Makes code cleaner and safer
#
# Avoids needing a separate try...finally block to close the file -->

# %% [markdown]
# QUES 9 -  What is the difference between multithreading and multiprocessing
# <!-- ANS 9 - The difference between multithreading and multiprocessing in Python lies in how they handle parallelism and make use of system resources, especially CPU cores.
#
# 🧵 Multithreading
# Runs multiple threads within a single process
#
# Threads share the same memory space
#
# Useful for I/O-bound tasks (e.g., file reading, network requests)
#
# Limited by the Global Interpreter Lock (GIL) in CPython, which allows only one thread to execute Python bytecode at a time
# 🧠 Multiprocessing
# Runs multiple processes, each with its own Python interpreter and memory space
#
# Bypasses the GIL → true parallel execution on multiple CPU cores
#
# Ideal for CPU-bound tasks (e.g., data processing, computations) -->

# %% [markdown]
# QUES 10 -  What are the advantages of using logging in a program ?
# <!-- ANS 10 Using logging in a Python program offers several important advantages over using print() statements. Logging provides a flexible, powerful, and standardized way to track what's happening in your application.
#
# ✅ Advantages of Using Logging
# 1. 🔍 Better Debugging and Monitoring
# Helps trace the flow of execution and data.
#
# Makes it easier to find bugs and understand what went wrong.
#
# 2. 🧠 Different Log Levels
# You can categorize messages by severity:
#
# DEBUG – Detailed information for debugging
#
# INFO – General events (e.g., app started)
#
# WARNING – Something unexpected happened
#
# ERROR – A problem occurred, but the app can continue
#
# CRITICAL – A serious error; program may crash
#
# This lets you filter messages depending on your environment (development vs production).
#
# 3. 📁 Output to Multiple Destinations
# Log messages can be written to:
#
# The console
#
# A file
#
# An external server
#
# Email, databases, or cloud platforms
#
# 4. 📊 Persistent Log Records
# Logs are stored, not lost like console output.
#
# Helps with post-mortem analysis or long-term monitoring.
#
# 5. 🛠️ Configurable and Structured
# You can format logs with:
#
# Timestamps
#
# Log level
#
# Module/function name
#
# Custom messages -->

# %% [markdown]
# QUES 11 - What is memory management in Python ?
# <!-- ANS 11 -Memory management in Python refers to how Python allocates, manages, and frees up memory for objects during program execution. It’s crucial for efficient performance and avoiding memory leaks.
#
# 🎯 Key Aspects of Memory Management in Python
# Automatic Memory Allocation
#
# When you create objects (like variables, lists, or classes), Python automatically allocates memory for them.
#
# Reference Counting
#
# Python uses reference counting to keep track of how many references point to each object.
#
# When an object’s reference count drops to zero (no references point to it), Python frees the memory.
#
# Garbage Collection
#
# Besides reference counting, Python has a garbage collector to clean up circular references (objects referencing each other).
#
# This runs periodically to find and delete unreachable objects.
#
# Memory Pools and Object Allocators
#
# Python uses internal memory pools (via the pymalloc allocator) to manage small objects efficiently.
#
# Large objects are handled differently, often directly by the operating system. -->

# %% [markdown]
# QUES 12 - What are the basic steps involved in exception handling in Python?
# <!-- ANS 12 - The basic steps involved in exception handling in Python typically follow this structure:
#
# 1. Identify the risky code
# The code section where an error might occur
# 2. Wrap risky code inside a try block
# Python attempts to execute this code.
# 3. Handle exceptions using except blocks
# Catch specific exceptions to handle errors gracefully.
# 4. (Optional) Use else block
# Code that runs only if no exceptions were raised in the try block -->

# %% [markdown]
# QUES 13 - Why is memory management important in Python ?
#  <!-- ANS 13 - Memory management is important in Python because it ensures your programs run efficiently, reliably, and without unnecessary resource waste. Here’s why:
#
# 🧠 Why Memory Management Matters in Python
# Prevents Memory Leaks
#
# Proper memory management helps avoid situations where memory is allocated but never freed, which can cause your program to consume more and more memory over time and eventually crash.
#
# Optimizes Performance
#
# Efficient use of memory speeds up program execution and reduces overhead, especially for large or complex applications.
#
# Automates Resource Handling
#
# Python’s automatic memory management (reference counting + garbage collection) frees developers from manual allocation and deallocation, reducing bugs related to memory.
#
# Manages Limited Resources
#
# Memory is a finite resource; good management ensures multiple programs can run smoothly without exhausting system memory.
#
# Improves Stability
#
# Proper cleanup of objects prevents crashes or unexpected behavior due to dangling references or corrupted data. -->

# %% [markdown]
# QUES 14 -  What is the role of try and except in exception handling ?
# <!-- ANS 14 - The role of try and except in Python’s exception handling is to detect and handle errors gracefully so your program doesn’t crash unexpectedly.
#
# 🎯 try block
# Contains the code that might raise an exception.
#
# Python attempts to execute this code normally.
# 🎯 except block
# Catches and handles the exception if one occurs in the try block.
#
# Lets you respond to specific errors and keep the program running. -->

# %% [markdown]
# QUES 15 -  How does Python's garbage collection system work ?
# <!-- ANS 15  Python’s garbage collection (GC) system is responsible for automatically freeing memory occupied by objects that are no longer needed, helping prevent memory leaks.
#
# 🧠 How Python’s Garbage Collection Works:
# 1. Reference Counting (Primary Mechanism)
# Every object has a reference count—the number of references pointing to it.
#
# When you create an object, the count increases.
#
# When a reference goes away (e.g., variable reassigned or deleted), the count decreases.
#
# When the reference count reaches zero, Python immediately deallocates the object’s memory. -->

# %% [markdown]
# QUES 16 - What is the purpose of the else block in exception handling ?
# <!-- ANS 16 - The else block in Python exception handling is used to define code that runs only if no exceptions were raised in the preceding try block.
#
# 🎯 Purpose of the else Block
# Runs when the try block succeeds without any exceptions
#
# Keeps the code cleaner and more readable by separating normal execution logic from error handling
#
# Useful for code that should only execute if everything in try went well -->

# %% [markdown]
# QUES 17 - What are the common logging levels in Python ?
# <!-- ANS 17 The common logging levels in Python, defined in the logging module, indicate the severity of events. They help control what kind of messages are recorded or displayed.
#
# 🪧 Common Logging Levels
# Level	Numeric    Value	       Description
# DEBUG	           10      	Detailed information, useful for diagnosing problems.
# INFO           	20	         General information about program execution.
# WARNING        	30	    An indication of a potential problem or important event.
# ERROR	          40	A more serious problem that caused a failure in some part of the program.
# CRITICAL      	50	A very serious error, often leading to program termination. -->

# %% [markdown]
# QUES 18 - What is the difference between os.fork() and multiprocessing in Python
# <!-- ANS 18 - Great question! Both os.fork() and the multiprocessing module in Python are used to create new processes, but they work quite differently and serve different purposes.
#
# 🔍 os.fork()
# What it does:
# Creates a child process by duplicating the current process (a direct clone).
#
# How it works:
# After a fork(), two nearly identical processes run — the parent and the child. Both continue executing from the point where the fork happened.
#
# Platform:
# Only available on Unix/Linux systems (not on Windows).
#
# Low-level:
# It’s a system call exposed by the OS, very primitive and manual.
#
# Use cases:
# When you want fine control over process creation and can handle the complexities of inter-process communication manually. -->

# %% [markdown]
# QUES 19 - What is the importance of closing a file in Python ?
# <!-- ANS 19 -Closing a file in Python is important because it ensures that:
#
# Data is properly saved (flushed) to disk:
# When you write to a file, the data is often buffered in memory first. Closing the file forces Python to flush these buffers, making sure all your changes are actually written to the file.
#
# System resources are released:
# Open files consume system resources like file descriptors. If you don’t close files, your program might run out of these resources, leading to errors.
#
# Prevents data corruption or loss:
# Properly closing files ensures file integrity. If a program crashes or exits without closing files, you risk losing data or corrupting the file.
#
# Allows other programs to access the file:
# Some operating systems lock files when they’re open. Closing releases these locks so other programs or processes can use the file. -->

# %% [markdown]
# QUES 20 - What is the difference between file.read() and file.readline() in Python?
# <!-- ANS  20 -Here’s the difference between file.read() and file.readline() in Python:
#
# 📖 file.read()
# Reads the entire contents of the file (or up to a specified number of bytes if you pass an argument).
#
# Returns the data as a single string.
#
# Useful when you want to work with the full file content at once.
# 📄 file.readline()
# Reads one line from the file at a time (up to the newline character).
#
# Returns a single line as a string (including the newline at the end).
#
# Useful for reading a file line-by-line, especially for large files. -->

# %% [markdown]
# QUES 21 - What is the logging module in Python used for
# <!-- ANS  21 - The logging module in Python is used for tracking events that happen when your software runs. It allows you to record messages that help you monitor, debug, and audit your programs.
#
# 🎯 What the logging Module Does
# Provides a flexible framework for emitting log messages from Python programs.
#
# Helps capture information about:
#
# Errors and exceptions
#
# Program flow and status updates
#
# Warnings and critical issues
#
# Supports different severity levels (DEBUG, INFO, WARNING, ERROR, CRITICAL).
#
# Allows logging to multiple destinations, such as:
#
# Console (standard output)
#
# Files
#
# Remote servers
#
# Email, etc. -->

# %% [markdown]
# QUES 22 -  What is the os module in Python used for in file handling?
# <!-- ANS 22 - The os module in Python provides a way to interact with the operating system, and it includes many functions useful for file handling and filesystem operations beyond just reading or writing file contents.
#
# 🎯 Purpose of the os Module in File Handling
# Manipulate files and directories at the OS level.
#
# Perform operations like:
#
# Creating, renaming, or deleting files and directories
#
# Changing and getting the current working directory
#
# Checking if files or directories exist
#
# Getting file properties (size, permissions, timestamps)
#
# Handling file paths (joining, splitting, normalizing) -->

# %% [markdown]
# QUES 23 -  What are the challenges associated with memory management in Python
# <!-- ANS 23 - Here are some common challenges associated with memory management in Python:
#
# 1. Circular References
# Objects that reference each other can create cycles.
#
# Python’s reference counting can’t free these automatically.
#
# The garbage collector handles cycles, but detecting and cleaning them adds overhead.
#
# 2. Memory Leaks
# Can happen if references to unused objects are unintentionally kept alive (e.g., via global variables or caches).
#
# Hard to detect because Python manages memory automatically.
#
# Leaks cause increased memory usage and can slow or crash programs.
#
# 3. Fragmentation
# Frequent allocation and deallocation can cause memory fragmentation.
#
# This can lead to inefficient use of memory and slow performance.
#
# 4. Large Object Management
# Python’s memory allocator (pymalloc) is optimized for small objects.
#
# Large objects may require special handling and can cause higher memory overhead.
#
# 5. Unpredictable Garbage Collection
# Garbage collector runs periodically, but timing is not deterministic.
#
# This can cause unpredictable pauses or performance hiccups.
#
# 6. Overhead of Garbage Collection
# The GC process itself consumes CPU time.
#
# Managing the trade-off between timely cleanup and performance can be tricky. -->

# %% [markdown]
# QUES 24 -  How do you raise an exception manually in Python ?
# <!-- ANS 24 - You can raise an exception manually in Python using the raise statement. This allows you to create and trigger an exception at any point in your code.
#
#  -->

# %% [markdown]
# QUES 25 - Why is it important to use multithreading in certain applications ?
#
#  <!-- ANS 25 - Using multithreading is important in certain applications because it allows your program to perform multiple tasks concurrently, improving efficiency and responsiveness. Here’s why multithreading matters:
#
# 🔑 Reasons to Use Multithreading
# Improves Performance for I/O-bound Tasks
#
# Tasks that spend a lot of time waiting for external resources (like file reading, network calls, or database queries) benefit because while one thread waits, others can run.
#
# Enhances Responsiveness
#
# In user interfaces or real-time applications, multithreading keeps the app responsive by running time-consuming tasks in the background.
#
# Better Resource Utilization
#
# Threads share the same memory space, so context switching is faster and less resource-intensive compared to multiprocessing.
#
# Simplifies Program Structure
#
# Using threads can make some concurrent programs simpler than managing multiple processes. -->

# %% [markdown]
# #**PRACTICAL QUESTIONS **

# %% [markdown]
# QUES 1 How can you open a file for writing in Python and write a string to it
# <!-- ANS 1 - You can open a file for writing in Python using the built-in open() function with mode 'w', and then write a string using the file object's write() method.
#
#  *  Explanation:
# 'w' mode opens the file for writing (creates the file if it doesn’t exist or truncates it if it does).
#
# Using a with statement ensures the file is automatically closed after writing.
#
# write() writes the string to the file. -->

# %%
with open('filename.txt', 'w') as file:
    file.write("Hello, world!")

# %% [markdown]
# QUES 2 -  Write a Python program to read the contents of a file and print each line

# %%
filename = "filename.txt" # Changed from "example.txt"

with open(filename, "r") as file:
    for line in file:
        print(line, end='')  # end='' avoids adding extra newlines
# Out:
# Hello, world!

# %% [markdown]
# QUES 3 - How would you handle a case where the file doesn't exist while trying to open it for reading

# %%
filename = "nonexistent.txt"

try:
    with open(filename, "r") as file:
        for line in file:
            print(line, end='')
except FileNotFoundError:
    print(f"Error: The file '{filename}' does not exist.")
# Out:
# Error: The file 'nonexistent.txt' does not exist.

# %% [markdown]
# QUES 4 - Write a Python script that reads from one file and writes its content to another file

# %%
source_file = "source.txt"
destination_file = "destination.txt"

try:
    with open(source_file, "r") as src, open(destination_file, "w") as dest:
        for line in src:
            dest.write(line)
    print("File copied successfully.")
except FileNotFoundError:
    print(f"Error: The file '{source_file}' does not exist.")
except IOError as e:
    print(f"I/O error occurred: {e}")
# Out:
# Error: The file 'source.txt' does not exist.

# %% [markdown]
# QUES 5 -  How would you catch and handle division by zero error in Python

# %%
try:
    result = 10 / 0
except ZeroDivisionError:
    print("Error: Cannot divide by zero!")
else:
    print("Result is", result)
# Out:
# Error: Cannot divide by zero!

# %% [markdown]
# QUES 6 - Write a Python program that logs an error message to a log file when a division by zero exception occurs

# %%
import logging

# Configure logging to write to a file with level ERROR
logging.basicConfig(filename='error.log', level=logging.ERROR,
                    format='%(asctime)s - %(levelname)s - %(message)s')

try:
    result = 10 / 0
except ZeroDivisionError as e:
    logging.error("Division by zero error occurred: %s", e)
    print("An error occurred. Check error.log for details.")
# Out:
# ERROR:root:Division by zero error occurred: division by zero
# An error occurred. Check error.log for details.

# %% [markdown]
# QUES 7 - How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module

# %%
import logging

logging.basicConfig(level=logging.DEBUG, format='%(levelname)s: %(message)s')

logging.debug("This is a debug message")
logging.info("This is an info message")
logging.warning("This is a warning")
logging.error("This is an error")
logging.critical("This is critical")
# Out:
# WARNING:root:This is a warning
# ERROR:root:This is an error
# CRITICAL:root:This is critical

# %% [markdown]
# QUES 8 - Write a program to handle a file opening error using exception handling

# %%
filename = "somefile.txt"

try:
    with open(filename, "r") as file:
        content = file.read()
        print(content)
except FileNotFoundError:
    print(f"Error: The file '{filename}' was not found.")
except IOError as e:
    print(f"An I/O error occurred: {e}")
# Out:
# Error: The file 'somefile.txt' was not found.

# %% [markdown]
# QUES 9  How can you read a file line by line and store its content in a list in Python
#
#  <!-- ANE 9 -You can read a file line by line and store its contents in a list using a simple with open() block and a list comprehension or loop.
#
#  -->

# %%
# Create the file "example.txt" if it doesn't exist
try:
    with open("example.txt", "w") as f:
        f.write("This is line 1\n")
        f.write("This is line 2\n")
        f.write("This is line 3\n")
except IOError as e:
    print(f"Error creating file: {e}")

# Now attempt to read the file
with open("example.txt", "r") as file:
    lines = file.readlines()

print(lines)
# Out:
# ['This is line 1\n', 'This is line 2\n', 'This is line 3\n']

# %% [markdown]
# QUES 10  - How can you append data to an existing file in Python
#
# <!-- ANS 10 - To append data to an existing file in Python, you open the file in append mode using 'a' (text mode) or 'ab' (binary mode), and then write to it. This adds data to the end of the file without overwriting its existing contents -->

# %%
with open("example.txt", "a") as file:
    file.write("This is a new line.\n")

# %% [markdown]
# QUES 11 - Write a Python program that uses a try-except block to handle an error when attempting to access a
# dictionary key that doesn't exist

# %%
# Sample dictionary
person = {
    "name": "Alice",
    "age": 30
}

try:
    # Attempt to access a key that might not exist
    print("City:", person["city"])
except KeyError as e:
    print(f"Error: The key '{e.args[0]}' does not exist in the dictionary.")
# Out:
# Error: The key 'city' does not exist in the dictionary.

# %% [markdown]
# QUES 12 - F Write a program that demonstrates using multiple except blocks to handle different types of exceptions

# %%
try:
    num1 = int(input("Enter a number: "))
    num2 = int(input("Enter another number: "))
    result = num1 / num2
    print("Result:", result)

    data = {"name": "Alice"}
    print("Age:", data["age"])  # This will raise KeyError

except ValueError:
    print("Error: You must enter a valid integer.")

except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")

except KeyError as e:
    print(f"Error: The key '{e.args[0]}' was not found in the dictionary.")

except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Enter a number: 34
# Enter another number: 24
# Result: 1.4166666666666667
# Error: The key 'age' was not found in the dictionary.

# %% [markdown]
# QUES 13 -How would you check if a file exists before attempting to read it in Python

# %%
import os

filename = "example.txt"

if os.path.exists(filename):
    with open(filename, "r") as file:
        content = file.read()
        print(content)
else:
    print(f"Error: The file '{filename}' does not exist.")
# Out:
# This is line 1
# This is line 2
# This is line 3
# This is a new line.

# %% [markdown]
# QUES 14 -Write a program that uses the logging module to log both informational and error messages

# %%
import logging

# Configure logging: write to 'app.log', include level and message
logging.basicConfig(
    filename='app.log',
    level=logging.DEBUG,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

# Log an informational message
logging.info("Program started successfully.")

try:
    x = int(input("Enter a number: "))
    y = int(input("Enter another number: "))
    result = x / y
    logging.info(f"Division successful: {x} / {y} = {result}")
except ZeroDivisionError as e:
    logging.error("Error: Division by zero.")
except ValueError as e:
    logging.error("Error: Invalid input. Please enter integers only.")
except Exception as e:
    logging.error(f"Unexpected error: {e}")

logging.info("Program ended.")
# Out:
# Enter a number: 6
# Enter another number: 0
# ERROR:root:Error: Division by zero.

# %% [markdown]
# QUES 15 - F Write a Python program that prints the content of a file and handles the case when the file is empty

# %%
def print_file_content(filename):
    try:
        with open(filename, 'r') as file:
            content = file.read()
            if content:
                print("File Content:")
                print(content)
            else:
                print("The file is empty.")
    except FileNotFoundError:
        print(f"Error: The file '{filename}' does not exist.")
    except IOError as e:
        print(f"An I/O error occurred: {e}")

# Example usage
filename = input("Enter the file name: ")
print_file_content(filename)
# Out:
# Enter the file name: RAJ
# Error: The file 'RAJ' does not exist.

# %% [markdown]
# QUES 16 - Demonstrate how to use memory profiling to check the memory usage of a small program

# %%
pip install memory-profiler
# Out:
# Collecting memory-profiler
#   Downloading memory_profiler-0.61.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from memory-profiler) (5.9.5)
# Downloading memory_profiler-0.61.0-py3-none-any.whl (31 kB)
# Installing collected packages: memory-profiler
# Successfully installed memory-profiler-0.61.0

# %%
# memory_example.py

from memory_profiler import profile

@profile
def create_large_list():
    large_list = [i for i in range(1000000)]
    return sum(large_list)

if __name__ == "__main__":
    create_large_list()
# Out:
# PYDEV DEBUGGER WARNING:
# sys.settrace() should not be used when the debugger is being used.
# This may cause the debugger to stop working correctly.
# If this is needed, please check:
# http://pydev.blogspot.com/2007/06/why-cant-pydev-debugger-work-with.html
# to see how to restore the debug tracing back correctly.
# Call Location:
#   File "/usr/local/lib/python3.11/dist-packages/memory_profiler.py", line 847, in enable
#     sys.settrace(self.trace_memory_usage)
# ERROR: Could not find file <ipython-input-29-b831560c0a6f>
# NOTE: %mprun can only be used on functions defined in physical files, and not in the IPython environment.
# PYDEV DEBUGGER WARNING:
# sys.settrace() should not be used when the debugger is being used.
# This may cause the debugger to stop working correctly.
# If this is needed, please check:
# http://pydev.blogspot.com/2007/06/why-cant-pydev-debugger-work-with.html
# to see how to restore the debug tracing back correctly.
# Call Location:
#   File "/usr/local/lib/python3.11/dist-packages/memory_profiler.py", line 850, in disable
#     sys.settrace(self._original_trace_function)

# %%
# !python -m memory_profiler memory_example.py
# Out:
# Could not find script memory_example.py

# %% [markdown]
# QUES 17 -  Write a Python program to create and write a list of numbers to a file, one number per lineF

# %%
def write_numbers_to_file(filename, numbers):
    try:
        with open(filename, 'w') as file:
            for number in numbers:
                file.write(f"{number}\n")
        print(f"Successfully wrote {len(numbers)} numbers to '{filename}'.")
    except IOError as e:
        print(f"An error occurred while writing to the file: {e}")

# Example usage
numbers = list(range(1, 11))  # Creates a list: [1, 2, ..., 10]
filename = "numbers.txt"
write_numbers_to_file(filename, numbers)
# Out:
# Successfully wrote 10 numbers to 'numbers.txt'.

# %% [markdown]
# QUES 18 -  How would you implement a basic logging setup that logs to a file with rotation after 1MB

# %%
import logging
from logging.handlers import RotatingFileHandler

# Create logger
logger = logging.getLogger('my_logger')
logger.setLevel(logging.DEBUG)  # Log all levels DEBUG and above

# Create a rotating file handler
handler = RotatingFileHandler('app.log', maxBytes=1_000_000, backupCount=3)
handler.setLevel(logging.DEBUG)

# Create formatter and add it to the handler
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)

# Add the handler to the logger
logger.addHandler(handler)

# Example logging
for i in range(10000):
    logger.debug(f"Logging line {i}")
# Out:
# Streaming output truncated to the last 5000 lines.
# DEBUG:my_logger:Logging line 5000
# DEBUG:my_logger:Logging line 5001
# DEBUG:my_logger:Logging line 5002
# DEBUG:my_logger:Logging line 5003
# DEBUG:my_logger:Logging line 5004
# DEBUG:my_logger:Logging line 5005
# DEBUG:my_logger:Logging line 5006
# DEBUG:my_logger:Logging line 5007
# DEBUG:my_logger:Logging line 5008
# DEBUG:my_logger:Logging line 5009
# DEBUG:my_logger:Logging line 5010
# DEBUG:my_logger:Logging line 5011
# DEBUG:my_logger:Logging line 5012
# DEBUG:my_logger:Logging line 5013
# DEBUG:my_logger:Logging line 5014
# DEBUG:my_logger:Logging line 5015
# DEBUG:my_logger:Logging line 5016
# DEBUG:my_logger:Logging line 5017
# DEBUG:my_logger:Logging line 5018
# DEBUG:my_logger:Logging line 5019
# DEBUG:my_logger:Logging line 5020
# DEBUG:my_logger:Logging line 5021
# DEBUG:my_logger:Logging line 5022
# DEBUG:my_logger:Logging line 5023
# DEBUG:my_logger:Logging line 5024
# DEBUG:my_logger:Logging line 5025
# DEBUG:my_logger:Logging line 5026
# DEBUG:my_logger:Logging line 5027
# DEBUG:my_logger:Logging line 5028
# DEBUG:my_logger:Logging line 5029
# DEBUG:my_logger:Logging line 5030
# DEBUG:my_logger:Logging line 5031
# DEBUG:my_logger:Logging line 5032
# DEBUG:my_logger:Logging line 5033
# DEBUG:my_logger:Logging line 5034
# DEBUG:my_logger:Logging line 5035
# DEBUG:my_logger:Logging line 5036
# DEBUG:my_logger:Logging line 5037
# DEBUG:my_logger:Logging line 5038
# DEBUG:my_logger:Logging line 5039
# DEBUG:my_logger:Logging line 5040
# DEBUG:my_logger:Logging line 5041
# DEBUG:my_logger:Logging line 5042
# DEBUG:my_logger:Logging line 5043
# DEBUG:my_logger:Logging line 5044
# DEBUG:my_logger:Logging line 5045
# DEBUG:my_logger:Logging line 5046
# DEBUG:my_logger:Logging line 5047
# DEBUG:my_logger:Logging line 5048
# DEBUG:my_logger:Logging line 5049
# DEBUG:my_logger:Logging line 5050
# DEBUG:my_logger:Logging line 5051
# DEBUG:my_logger:Logging line 5052
# DEBUG:my_logger:Logging line 5053
# DEBUG:my_logger:Logging line 5054
# DEBUG:my_logger:Logging line 5055
# DEBUG:my_logger:Logging line 5056
# DEBUG:my_logger:Logging line 5057
# DEBUG:my_logger:Logging line 5058
# DEBUG:my_logger:Logging line 5059
# DEBUG:my_logger:Logging line 5060
# DEBUG:my_logger:Logging line 5061
# DEBUG:my_logger:Logging line 5062
# DEBUG:my_logger:Logging line 5063
# DEBUG:my_logger:Logging line 5064
# DEBUG:my_logger:Logging line 5065
# DEBUG:my_logger:Logging line 5066
# DEBUG:my_logger:Logging line 5067
# DEBUG:my_logger:Logging line 5068
# DEBUG:my_logger:Logging line 5069
# DEBUG:my_logger:Logging line 5070
# DEBUG:my_logger:Logging line 5071
# DEBUG:my_logger:Logging line 5072
# DEBUG:my_logger:Logging line 5073
# DEBUG:my_logger:Logging line 5074
# DEBUG:my_logger:Logging line 5075
# DEBUG:my_logger:Logging line 5076
# DEBUG:my_logger:Logging line 5077
# DEBUG:my_logger:Logging line 5078
# DEBUG:my_logger:Logging line 5079
# DEBUG:my_logger:Logging line 5080
# DEBUG:my_logger:Logging line 5081
# DEBUG:my_logger:Logging line 5082
# DEBUG:my_logger:Logging line 5083
# DEBUG:my_logger:Logging line 5084
# DEBUG:my_logger:Logging line 5085
# DEBUG:my_logger:Logging line 5086
# DEBUG:my_logger:Logging line 5087
# DEBUG:my_logger:Logging line 5088
# DEBUG:my_logger:Logging line 5089
# DEBUG:my_logger:Logging line 5090
# DEBUG:my_logger:Logging line 5091
# DEBUG:my_logger:Logging line 5092
# DEBUG:my_logger:Logging line 5093
# DEBUG:my_logger:Logging line 5094
# DEBUG:my_logger:Logging line 5095
# DEBUG:my_logger:Logging line 5096
# DEBUG:my_logger:Logging line 5097
# DEBUG:my_logger:Logging line 5098
# DEBUG:my_logger:Logging line 5099
# DEBUG:my_logger:Logging line 5100
# DEBUG:my_logger:Logging line 5101
# DEBUG:my_logger:Logging line 5102
# DEBUG:my_logger:Logging line 5103
# DEBUG:my_logger:Logging line 5104
# DEBUG:my_logger:Logging line 5105
# DEBUG:my_logger:Logging line 5106
# DEBUG:my_logger:Logging line 5107
# DEBUG:my_logger:Logging line 5108
# DEBUG:my_logger:Logging line 5109
# DEBUG:my_logger:Logging line 5110
# DEBUG:my_logger:Logging line 5111
# DEBUG:my_logger:Logging line 5112
# DEBUG:my_logger:Logging line 5113
# DEBUG:my_logger:Logging line 5114
# DEBUG:my_logger:Logging line 5115
# DEBUG:my_logger:Logging line 5116
# DEBUG:my_logger:Logging line 5117
# DEBUG:my_logger:Logging line 5118
# DEBUG:my_logger:Logging line 5119
# DEBUG:my_logger:Logging line 5120
# DEBUG:my_logger:Logging line 5121
# DEBUG:my_logger:Logging line 5122
# DEBUG:my_logger:Logging line 5123
# DEBUG:my_logger:Logging line 5124
# DEBUG:my_logger:Logging line 5125
# DEBUG:my_logger:Logging line 5126
# DEBUG:my_logger:Logging line 5127
# DEBUG:my_logger:Logging line 5128
# DEBUG:my_logger:Logging line 5129
# DEBUG:my_logger:Logging line 5130
# DEBUG:my_logger:Logging line 5131
# DEBUG:my_logger:Logging line 5132
# DEBUG:my_logger:Logging line 5133
# DEBUG:my_logger:Logging line 5134
# DEBUG:my_logger:Logging line 5135
# DEBUG:my_logger:Logging line 5136
# DEBUG:my_logger:Logging line 5137
# DEBUG:my_logger:Logging line 5138
# DEBUG:my_logger:Logging line 5139
# DEBUG:my_logger:Logging line 5140
# DEBUG:my_logger:Logging line 5141
# DEBUG:my_logger:Logging line 5142
# DEBUG:my_logger:Logging line 5143
# DEBUG:my_logger:Logging line 5144
# DEBUG:my_logger:Logging line 5145
# DEBUG:my_logger:Logging line 5146
# DEBUG:my_logger:Logging line 5147
# DEBUG:my_logger:Logging line 5148
# DEBUG:my_logger:Logging line 5149
# DEBUG:my_logger:Logging line 5150
# DEBUG:my_logger:Logging line 5151
# DEBUG:my_logger:Logging line 5152
# DEBUG:my_logger:Logging line 5153
# DEBUG:my_logger:Logging line 5154
# DEBUG:my_logger:Logging line 5155
# DEBUG:my_logger:Logging line 5156
# DEBUG:my_logger:Logging line 5157
# DEBUG:my_logger:Logging line 5158
# DEBUG:my_logger:Logging line 5159
# DEBUG:my_logger:Logging line 5160
# DEBUG:my_logger:Logging line 5161
# DEBUG:my_logger:Logging line 5162
# DEBUG:my_logger:Logging line 5163
# DEBUG:my_logger:Logging line 5164
# DEBUG:my_logger:Logging line 5165
# DEBUG:my_logger:Logging line 5166
# DEBUG:my_logger:Logging line 5167
# DEBUG:my_logger:Logging line 5168
# DEBUG:my_logger:Logging line 5169
# DEBUG:my_logger:Logging line 5170
# DEBUG:my_logger:Logging line 5171
# DEBUG:my_logger:Logging line 5172
# DEBUG:my_logger:Logging line 5173
# DEBUG:my_logger:Logging line 5174
# DEBUG:my_logger:Logging line 5175
# DEBUG:my_logger:Logging line 5176
# DEBUG:my_logger:Logging line 5177
# DEBUG:my_logger:Logging line 5178
# DEBUG:my_logger:Logging line 5179
# DEBUG:my_logger:Logging line 5180
# DEBUG:my_logger:Logging line 5181
# DEBUG:my_logger:Logging line 5182
# DEBUG:my_logger:Logging line 5183
# DEBUG:my_logger:Logging line 5184
# DEBUG:my_logger:Logging line 5185
# DEBUG:my_logger:Logging line 5186
# DEBUG:my_logger:Logging line 5187
# DEBUG:my_logger:Logging line 5188
# DEBUG:my_logger:Logging line 5189
# DEBUG:my_logger:Logging line 5190
# DEBUG:my_logger:Logging line 5191
# DEBUG:my_logger:Logging line 5192
# DEBUG:my_logger:Logging line 5193
# DEBUG:my_logger:Logging line 5194
# DEBUG:my_logger:Logging line 5195
# DEBUG:my_logger:Logging line 5196
# DEBUG:my_logger:Logging line 5197
# DEBUG:my_logger:Logging line 5198
# DEBUG:my_logger:Logging line 5199
# DEBUG:my_logger:Logging line 5200
# DEBUG:my_logger:Logging line 5201
# DEBUG:my_logger:Logging line 5202
# DEBUG:my_logger:Logging line 5203
# DEBUG:my_logger:Logging line 5204
# DEBUG:my_logger:Logging line 5205
# DEBUG:my_logger:Logging line 5206
# DEBUG:my_logger:Logging line 5207
# DEBUG:my_logger:Logging line 5208
# DEBUG:my_logger:Logging line 5209
# DEBUG:my_logger:Logging line 5210
# DEBUG:my_logger:Logging line 5211
# DEBUG:my_logger:Logging line 5212
# DEBUG:my_logger:Logging line 5213
# DEBUG:my_logger:Logging line 5214
# DEBUG:my_logger:Logging line 5215
# DEBUG:my_logger:Logging line 5216
# DEBUG:my_logger:Logging line 5217
# DEBUG:my_logger:Logging line 5218
# DEBUG:my_logger:Logging line 5219
# DEBUG:my_logger:Logging line 5220
# DEBUG:my_logger:Logging line 5221
# DEBUG:my_logger:Logging line 5222
# DEBUG:my_logger:Logging line 5223
# DEBUG:my_logger:Logging line 5224
# DEBUG:my_logger:Logging line 5225
# DEBUG:my_logger:Logging line 5226
# DEBUG:my_logger:Logging line 5227
# DEBUG:my_logger:Logging line 5228
# DEBUG:my_logger:Logging line 5229
# DEBUG:my_logger:Logging line 5230
# DEBUG:my_logger:Logging line 5231
# DEBUG:my_logger:Logging line 5232
# DEBUG:my_logger:Logging line 5233
# DEBUG:my_logger:Logging line 5234
# DEBUG:my_logger:Logging line 5235
# DEBUG:my_logger:Logging line 5236
# DEBUG:my_logger:Logging line 5237
# DEBUG:my_logger:Logging line 5238
# DEBUG:my_logger:Logging line 5239
# DEBUG:my_logger:Logging line 5240
# DEBUG:my_logger:Logging line 5241
# DEBUG:my_logger:Logging line 5242
# DEBUG:my_logger:Logging line 5243
# DEBUG:my_logger:Logging line 5244
# DEBUG:my_logger:Logging line 5245
# DEBUG:my_logger:Logging line 5246
# DEBUG:my_logger:Logging line 5247
# DEBUG:my_logger:Logging line 5248
# DEBUG:my_logger:Logging line 5249
# DEBUG:my_logger:Logging line 5250
# DEBUG:my_logger:Logging line 5251
# DEBUG:my_logger:Logging line 5252
# DEBUG:my_logger:Logging line 5253
# DEBUG:my_logger:Logging line 5407
# DEBUG:my_logger:Logging line 5408
# DEBUG:my_logger:Logging line 5409
# DEBUG:my_logger:Logging line 5410
# DEBUG:my_logger:Logging line 5411
# DEBUG:my_logger:Logging line 5412
# DEBUG:my_logger:Logging line 5413
# DEBUG:my_logger:Logging line 5414
# DEBUG:my_logger:Logging line 5415
# DEBUG:my_logger:Logging line 5416
# DEBUG:my_logger:Logging line 5417
# DEBUG:my_logger:Logging line 5418
# DEBUG:my_logger:Logging line 5419
# DEBUG:my_logger:Logging line 5420
# DEBUG:my_logger:Logging line 5421
# DEBUG:my_logger:Logging line 5422
# DEBUG:my_logger:Logging line 5423
# DEBUG:my_logger:Logging line 5424
# DEBUG:my_logger:Logging line 5425
# DEBUG:my_logger:Logging line 5426
# DEBUG:my_logger:Logging line 5427
# DEBUG:my_logger:Logging line 5428
# DEBUG:my_logger:Logging line 5429
# DEBUG:my_logger:Logging line 5430
# DEBUG:my_logger:Logging line 5431
# DEBUG:my_logger:Logging line 5432
# DEBUG:my_logger:Logging line 5433
# DEBUG:my_logger:Logging line 5434
# DEBUG:my_logger:Logging line 5435
# DEBUG:my_logger:Logging line 5436
# DEBUG:my_logger:Logging line 5437
# DEBUG:my_logger:Logging line 5438
# DEBUG:my_logger:Logging line 5439
# DEBUG:my_logger:Logging line 5440
# DEBUG:my_logger:Logging line 5441
# DEBUG:my_logger:Logging line 5442
# DEBUG:my_logger:Logging line 5443
# DEBUG:my_logger:Logging line 5444
# DEBUG:my_logger:Logging line 5445
# DEBUG:my_logger:Logging line 5446
# DEBUG:my_logger:Logging line 5447
# DEBUG:my_logger:Logging line 5448
# DEBUG:my_logger:Logging line 5449
# DEBUG:my_logger:Logging line 5450
# DEBUG:my_logger:Logging line 5451
# DEBUG:my_logger:Logging line 5452
# DEBUG:my_logger:Logging line 5453
# DEBUG:my_logger:Logging line 5454
# DEBUG:my_logger:Logging line 5455
# DEBUG:my_logger:Logging line 5456
# DEBUG:my_logger:Logging line 5457
# DEBUG:my_logger:Logging line 5458
# DEBUG:my_logger:Logging line 5459
# DEBUG:my_logger:Logging line 5460
# DEBUG:my_logger:Logging line 5461
# DEBUG:my_logger:Logging line 5462
# DEBUG:my_logger:Logging line 5463
# DEBUG:my_logger:Logging line 5464
# DEBUG:my_logger:Logging line 5465
# DEBUG:my_logger:Logging line 5466
# DEBUG:my_logger:Logging line 5467
# DEBUG:my_logger:Logging line 5468
# DEBUG:my_logger:Logging line 5469
# DEBUG:my_logger:Logging line 5470
# DEBUG:my_logger:Logging line 5471
# DEBUG:my_logger:Logging line 5472
# DEBUG:my_logger:Logging line 5473
# DEBUG:my_logger:Logging line 5474
# DEBUG:my_logger:Logging line 5475
# DEBUG:my_logger:Logging line 5476
# DEBUG:my_logger:Logging line 5477
# DEBUG:my_logger:Logging line 5478
# DEBUG:my_logger:Logging line 5479
# DEBUG:my_logger:Logging line 5480
# DEBUG:my_logger:Logging line 5481
# DEBUG:my_logger:Logging line 5482
# DEBUG:my_logger:Logging line 5483
# DEBUG:my_logger:Logging line 5867
# DEBUG:my_logger:Logging line 5868
# DEBUG:my_logger:Logging line 5869
# DEBUG:my_logger:Logging line 5870
# DEBUG:my_logger:Logging line 5871
# DEBUG:my_logger:Logging line 5872
# DEBUG:my_logger:Logging line 5873
# DEBUG:my_logger:Logging line 5874
# DEBUG:my_logger:Logging line 5875
# DEBUG:my_logger:Logging line 5876
# DEBUG:my_logger:Logging line 5877
# DEBUG:my_logger:Logging line 5878
# DEBUG:my_logger:Logging line 5879
# DEBUG:my_logger:Logging line 5880
# DEBUG:my_logger:Logging line 5881
# DEBUG:my_logger:Logging line 5882
# DEBUG:my_logger:Logging line 5883
# DEBUG:my_logger:Logging line 5884
# DEBUG:my_logger:Logging line 5885
# DEBUG:my_logger:Logging line 5886
# DEBUG:my_logger:Logging line 5887
# DEBUG:my_logger:Logging line 5888
# DEBUG:my_logger:Logging line 5889
# DEBUG:my_logger:Logging line 5890
# DEBUG:my_logger:Logging line 5891
# DEBUG:my_logger:Logging line 5892
# DEBUG:my_logger:Logging line 5893
# DEBUG:my_logger:Logging line 5894
# DEBUG:my_logger:Logging line 5895
# DEBUG:my_logger:Logging line 5896
# DEBUG:my_logger:Logging line 5897
# DEBUG:my_logger:Logging line 5898
# DEBUG:my_logger:Logging line 5899
# DEBUG:my_logger:Logging line 5900
# DEBUG:my_logger:Logging line 5901
# DEBUG:my_logger:Logging line 5902
# DEBUG:my_logger:Logging line 5903
# DEBUG:my_logger:Logging line 5904
# DEBUG:my_logger:Logging line 5905
# DEBUG:my_logger:Logging line 5906
# DEBUG:my_logger:Logging line 5907
# DEBUG:my_logger:Logging line 5908
# DEBUG:my_logger:Logging line 5909
# DEBUG:my_logger:Logging line 5910
# DEBUG:my_logger:Logging line 5911
# DEBUG:my_logger:Logging line 5912
# DEBUG:my_logger:Logging line 5913
# DEBUG:my_logger:Logging line 5914
# DEBUG:my_logger:Logging line 5915
# DEBUG:my_logger:Logging line 5916
# DEBUG:my_logger:Logging line 5917
# DEBUG:my_logger:Logging line 5918
# DEBUG:my_logger:Logging line 5919
# DEBUG:my_logger:Logging line 5920
# DEBUG:my_logger:Logging line 5921
# DEBUG:my_logger:Logging line 5922
# DEBUG:my_logger:Logging line 5923
# DEBUG:my_logger:Logging line 5924
# DEBUG:my_logger:Logging line 5925
# DEBUG:my_logger:Logging line 5926
# DEBUG:my_logger:Logging line 5927
# DEBUG:my_logger:Logging line 5928
# DEBUG:my_logger:Logging line 5929
# DEBUG:my_logger:Logging line 5930
# DEBUG:my_logger:Logging line 5931
# DEBUG:my_logger:Logging line 5932
# DEBUG:my_logger:Logging line 5933
# DEBUG:my_logger:Logging line 5934
# DEBUG:my_logger:Logging line 5935
# DEBUG:my_logger:Logging line 5936
# DEBUG:my_logger:Logging line 5937
# DEBUG:my_logger:Logging line 5938
# DEBUG:my_logger:Logging line 5939
# DEBUG:my_logger:Logging line 5940
# DEBUG:my_logger:Logging line 5941
# DEBUG:my_logger:Logging line 5942
# DEBUG:my_logger:Logging line 5943
# DEBUG:my_logger:Logging line 6020
# DEBUG:my_logger:Logging line 6021
# DEBUG:my_logger:Logging line 6022
# DEBUG:my_logger:Logging line 6023
# DEBUG:my_logger:Logging line 6024
# DEBUG:my_logger:Logging line 6025
# DEBUG:my_logger:Logging line 6026
# DEBUG:my_logger:Logging line 6027
# DEBUG:my_logger:Logging line 6028
# DEBUG:my_logger:Logging line 6029
# DEBUG:my_logger:Logging line 6030
# DEBUG:my_logger:Logging line 6031
# DEBUG:my_logger:Logging line 6032
# DEBUG:my_logger:Logging line 6033
# DEBUG:my_logger:Logging line 6034
# DEBUG:my_logger:Logging line 6035
# DEBUG:my_logger:Logging line 6036
# DEBUG:my_logger:Logging line 6037
# DEBUG:my_logger:Logging line 6038
# DEBUG:my_logger:Logging line 6039
# DEBUG:my_logger:Logging line 6040
# DEBUG:my_logger:Logging line 6041
# DEBUG:my_logger:Logging line 6042
# DEBUG:my_logger:Logging line 6043
# DEBUG:my_logger:Logging line 6044
# DEBUG:my_logger:Logging line 6045
# DEBUG:my_logger:Logging line 6046
# DEBUG:my_logger:Logging line 6047
# DEBUG:my_logger:Logging line 6048
# DEBUG:my_logger:Logging line 6049
# DEBUG:my_logger:Logging line 6050
# DEBUG:my_logger:Logging line 6051
# DEBUG:my_logger:Logging line 6052
# DEBUG:my_logger:Logging line 6053
# DEBUG:my_logger:Logging line 6054
# DEBUG:my_logger:Logging line 6055
# DEBUG:my_logger:Logging line 6056
# DEBUG:my_logger:Logging line 6057
# DEBUG:my_logger:Logging line 6058
# DEBUG:my_logger:Logging line 6059
# DEBUG:my_logger:Logging line 6060
# DEBUG:my_logger:Logging line 6061
# DEBUG:my_logger:Logging line 6062
# DEBUG:my_logger:Logging line 6063
# DEBUG:my_logger:Logging line 6064
# DEBUG:my_logger:Logging line 6065
# DEBUG:my_logger:Logging line 6066
# DEBUG:my_logger:Logging line 6067
# DEBUG:my_logger:Logging line 6068
# DEBUG:my_logger:Logging line 6069
# DEBUG:my_logger:Logging line 6070
# DEBUG:my_logger:Logging line 6071
# DEBUG:my_logger:Logging line 6072
# DEBUG:my_logger:Logging line 6073
# DEBUG:my_logger:Logging line 6074
# DEBUG:my_logger:Logging line 6075
# DEBUG:my_logger:Logging line 6076
# DEBUG:my_logger:Logging line 6077
# DEBUG:my_logger:Logging line 6078
# DEBUG:my_logger:Logging line 6079
# DEBUG:my_logger:Logging line 6080
# DEBUG:my_logger:Logging line 6081
# DEBUG:my_logger:Logging line 6082
# DEBUG:my_logger:Logging line 6083
# DEBUG:my_logger:Logging line 6084
# DEBUG:my_logger:Logging line 6085
# DEBUG:my_logger:Logging line 6086
# DEBUG:my_logger:Logging line 6087
# DEBUG:my_logger:Logging line 6088
# DEBUG:my_logger:Logging line 6089
# DEBUG:my_logger:Logging line 6090
# DEBUG:my_logger:Logging line 6091
# DEBUG:my_logger:Logging line 6092
# DEBUG:my_logger:Logging line 6093
# DEBUG:my_logger:Logging line 6094
# DEBUG:my_logger:Logging line 6095
# DEBUG:my_logger:Logging line 6096
# DEBUG:my_logger:Logging line 6097
# DEBUG:my_logger:Logging line 6098
# DEBUG:my_logger:Logging line 6099
# DEBUG:my_logger:Logging line 6100
# DEBUG:my_logger:Logging line 6101
# DEBUG:my_logger:Logging line 6102
# DEBUG:my_logger:Logging line 6103
# DEBUG:my_logger:Logging line 6104
# DEBUG:my_logger:Logging line 6105
# DEBUG:my_logger:Logging line 6106
# DEBUG:my_logger:Logging line 6107
# DEBUG:my_logger:Logging line 6108
# DEBUG:my_logger:Logging line 6109
# DEBUG:my_logger:Logging line 6110
# DEBUG:my_logger:Logging line 6111
# DEBUG:my_logger:Logging line 6112
# DEBUG:my_logger:Logging line 6113
# DEBUG:my_logger:Logging line 6114
# DEBUG:my_logger:Logging line 6115
# DEBUG:my_logger:Logging line 6116
# DEBUG:my_logger:Logging line 6117
# DEBUG:my_logger:Logging line 6118
# DEBUG:my_logger:Logging line 6119
# DEBUG:my_logger:Logging line 6120
# DEBUG:my_logger:Logging line 6121
# DEBUG:my_logger:Logging line 6122
# DEBUG:my_logger:Logging line 6123
# DEBUG:my_logger:Logging line 6124
# DEBUG:my_logger:Logging line 6125
# DEBUG:my_logger:Logging line 6126
# DEBUG:my_logger:Logging line 6127
# DEBUG:my_logger:Logging line 6128
# DEBUG:my_logger:Logging line 6129
# DEBUG:my_logger:Logging line 6130
# DEBUG:my_logger:Logging line 6131
# DEBUG:my_logger:Logging line 6132
# DEBUG:my_logger:Logging line 6133
# DEBUG:my_logger:Logging line 6134
# DEBUG:my_logger:Logging line 6135
# DEBUG:my_logger:Logging line 6136
# DEBUG:my_logger:Logging line 6137
# DEBUG:my_logger:Logging line 6138
# DEBUG:my_logger:Logging line 6139
# DEBUG:my_logger:Logging line 6140
# DEBUG:my_logger:Logging line 6141
# DEBUG:my_logger:Logging line 6142
# DEBUG:my_logger:Logging line 6143
# DEBUG:my_logger:Logging line 6144
# DEBUG:my_logger:Logging line 6145
# DEBUG:my_logger:Logging line 6146
# DEBUG:my_logger:Logging line 6147
# DEBUG:my_logger:Logging line 6148
# DEBUG:my_logger:Logging line 6149
# DEBUG:my_logger:Logging line 6150
# DEBUG:my_logger:Logging line 6151
# DEBUG:my_logger:Logging line 6152
# DEBUG:my_logger:Logging line 6153
# DEBUG:my_logger:Logging line 6154
# DEBUG:my_logger:Logging line 6155
# DEBUG:my_logger:Logging line 6156
# DEBUG:my_logger:Logging line 6157
# DEBUG:my_logger:Logging line 6158
# DEBUG:my_logger:Logging line 6159
# DEBUG:my_logger:Logging line 6160
# DEBUG:my_logger:Logging line 6161
# DEBUG:my_logger:Logging line 6162
# DEBUG:my_logger:Logging line 6163
# DEBUG:my_logger:Logging line 6164
# DEBUG:my_logger:Logging line 6165
# DEBUG:my_logger:Logging line 6166
# DEBUG:my_logger:Logging line 6167
# DEBUG:my_logger:Logging line 6168
# DEBUG:my_logger:Logging line 6169
# DEBUG:my_logger:Logging line 6170
# DEBUG:my_logger:Logging line 6171
# DEBUG:my_logger:Logging line 6172
# DEBUG:my_logger:Logging line 6173
# DEBUG:my_logger:Logging line 6174
# DEBUG:my_logger:Logging line 6175
# DEBUG:my_logger:Logging line 6176
# DEBUG:my_logger:Logging line 6177
# DEBUG:my_logger:Logging line 6178
# DEBUG:my_logger:Logging line 6179
# DEBUG:my_logger:Logging line 6180
# DEBUG:my_logger:Logging line 6181
# DEBUG:my_logger:Logging line 6182
# DEBUG:my_logger:Logging line 6183
# DEBUG:my_logger:Logging line 6184
# DEBUG:my_logger:Logging line 6185
# DEBUG:my_logger:Logging line 6186
# DEBUG:my_logger:Logging line 6187
# DEBUG:my_logger:Logging line 6188
# DEBUG:my_logger:Logging line 6189
# DEBUG:my_logger:Logging line 6190
# DEBUG:my_logger:Logging line 6191
# DEBUG:my_logger:Logging line 6192
# DEBUG:my_logger:Logging line 6193
# DEBUG:my_logger:Logging line 6194
# DEBUG:my_logger:Logging line 6195
# DEBUG:my_logger:Logging line 6196
# DEBUG:my_logger:Logging line 6197
# DEBUG:my_logger:Logging line 6198
# DEBUG:my_logger:Logging line 6199
# DEBUG:my_logger:Logging line 6200
# DEBUG:my_logger:Logging line 6201
# DEBUG:my_logger:Logging line 6202
# DEBUG:my_logger:Logging line 6203
# DEBUG:my_logger:Logging line 6204
# DEBUG:my_logger:Logging line 6205
# DEBUG:my_logger:Logging line 6206
# DEBUG:my_logger:Logging line 6207
# DEBUG:my_logger:Logging line 6208
# DEBUG:my_logger:Logging line 6209
# DEBUG:my_logger:Logging line 6210
# DEBUG:my_logger:Logging line 6211
# DEBUG:my_logger:Logging line 6212
# DEBUG:my_logger:Logging line 6213
# DEBUG:my_logger:Logging line 6214
# DEBUG:my_logger:Logging line 6215
# DEBUG:my_logger:Logging line 6216
# DEBUG:my_logger:Logging line 6217
# DEBUG:my_logger:Logging line 6218
# DEBUG:my_logger:Logging line 6219
# DEBUG:my_logger:Logging line 6220
# DEBUG:my_logger:Logging line 6221
# DEBUG:my_logger:Logging line 6222
# DEBUG:my_logger:Logging line 6223
# DEBUG:my_logger:Logging line 6224
# DEBUG:my_logger:Logging line 6225
# DEBUG:my_logger:Logging line 6226
# DEBUG:my_logger:Logging line 6227
# DEBUG:my_logger:Logging line 6228
# DEBUG:my_logger:Logging line 6229
# DEBUG:my_logger:Logging line 6230
# DEBUG:my_logger:Logging line 6231
# DEBUG:my_logger:Logging line 6232
# DEBUG:my_logger:Logging line 6233
# DEBUG:my_logger:Logging line 6234
# DEBUG:my_logger:Logging line 6235
# DEBUG:my_logger:Logging line 6236
# DEBUG:my_logger:Logging line 6237
# DEBUG:my_logger:Logging line 6238
# DEBUG:my_logger:Logging line 6239
# DEBUG:my_logger:Logging line 6240
# DEBUG:my_logger:Logging line 6241
# DEBUG:my_logger:Logging line 6242
# DEBUG:my_logger:Logging line 6243
# DEBUG:my_logger:Logging line 6244
# DEBUG:my_logger:Logging line 6245
# DEBUG:my_logger:Logging line 6246
# DEBUG:my_logger:Logging line 6247
# DEBUG:my_logger:Logging line 6248
# DEBUG:my_logger:Logging line 6249
# DEBUG:my_logger:Logging line 6250
# DEBUG:my_logger:Logging line 6251
# DEBUG:my_logger:Logging line 6252
# DEBUG:my_logger:Logging line 6253
# DEBUG:my_logger:Logging line 6254
# DEBUG:my_logger:Logging line 6255
# DEBUG:my_logger:Logging line 6256
# DEBUG:my_logger:Logging line 6257
# DEBUG:my_logger:Logging line 6258
# DEBUG:my_logger:Logging line 6259
# DEBUG:my_logger:Logging line 6260
# DEBUG:my_logger:Logging line 6261
# DEBUG:my_logger:Logging line 6262
# DEBUG:my_logger:Logging line 6263
# DEBUG:my_logger:Logging line 6264
# DEBUG:my_logger:Logging line 6265
# DEBUG:my_logger:Logging line 6266
# DEBUG:my_logger:Logging line 6267
# DEBUG:my_logger:Logging line 6268
# DEBUG:my_logger:Logging line 6269
# DEBUG:my_logger:Logging line 6270
# DEBUG:my_logger:Logging line 6271
# DEBUG:my_logger:Logging line 6272
# DEBUG:my_logger:Logging line 6273
# DEBUG:my_logger:Logging line 6274
# DEBUG:my_logger:Logging line 6275
# DEBUG:my_logger:Logging line 6276
# DEBUG:my_logger:Logging line 6277
# DEBUG:my_logger:Logging line 6278
# DEBUG:my_logger:Logging line 6279
# DEBUG:my_logger:Logging line 6280
# DEBUG:my_logger:Logging line 6281
# DEBUG:my_logger:Logging line 6282
# DEBUG:my_logger:Logging line 6283
# DEBUG:my_logger:Logging line 6284
# DEBUG:my_logger:Logging line 6285
# DEBUG:my_logger:Logging line 6286
# DEBUG:my_logger:Logging line 6287
# DEBUG:my_logger:Logging line 6288
# DEBUG:my_logger:Logging line 6289
# DEBUG:my_logger:Logging line 6290
# DEBUG:my_logger:Logging line 6291
# DEBUG:my_logger:Logging line 6292
# DEBUG:my_logger:Logging line 6293
# DEBUG:my_logger:Logging line 6294
# DEBUG:my_logger:Logging line 6295
# DEBUG:my_logger:Logging line 6296
# DEBUG:my_logger:Logging line 6297
# DEBUG:my_logger:Logging line 6298
# DEBUG:my_logger:Logging line 6299
# DEBUG:my_logger:Logging line 6300
# DEBUG:my_logger:Logging line 6301
# DEBUG:my_logger:Logging line 6302
# DEBUG:my_logger:Logging line 6303
# DEBUG:my_logger:Logging line 6304
# DEBUG:my_logger:Logging line 6305
# DEBUG:my_logger:Logging line 6306
# DEBUG:my_logger:Logging line 6307
# DEBUG:my_logger:Logging line 6308
# DEBUG:my_logger:Logging line 6309
# DEBUG:my_logger:Logging line 6310
# DEBUG:my_logger:Logging line 6311
# DEBUG:my_logger:Logging line 6312
# DEBUG:my_logger:Logging line 6313
# DEBUG:my_logger:Logging line 6314
# DEBUG:my_logger:Logging line 6315
# DEBUG:my_logger:Logging line 6316
# DEBUG:my_logger:Logging line 6317
# DEBUG:my_logger:Logging line 6318
# DEBUG:my_logger:Logging line 6319
# DEBUG:my_logger:Logging line 6320
# DEBUG:my_logger:Logging line 6321
# DEBUG:my_logger:Logging line 6322
# DEBUG:my_logger:Logging line 6323
# DEBUG:my_logger:Logging line 6324
# DEBUG:my_logger:Logging line 6325
# DEBUG:my_logger:Logging line 6326
# DEBUG:my_logger:Logging line 6327
# DEBUG:my_logger:Logging line 6328
# DEBUG:my_logger:Logging line 6329
# DEBUG:my_logger:Logging line 6330
# DEBUG:my_logger:Logging line 6331
# DEBUG:my_logger:Logging line 6332
# DEBUG:my_logger:Logging line 6333
# DEBUG:my_logger:Logging line 6334
# DEBUG:my_logger:Logging line 6335
# DEBUG:my_logger:Logging line 6336
# DEBUG:my_logger:Logging line 6337
# DEBUG:my_logger:Logging line 6338
# DEBUG:my_logger:Logging line 6339
# DEBUG:my_logger:Logging line 6340
# DEBUG:my_logger:Logging line 6341
# DEBUG:my_logger:Logging line 6342
# DEBUG:my_logger:Logging line 6343
# DEBUG:my_logger:Logging line 6344
# DEBUG:my_logger:Logging line 6345
# DEBUG:my_logger:Logging line 6346
# DEBUG:my_logger:Logging line 6347
# DEBUG:my_logger:Logging line 6348
# DEBUG:my_logger:Logging line 6349
# DEBUG:my_logger:Logging line 6350
# DEBUG:my_logger:Logging line 6351
# DEBUG:my_logger:Logging line 6352
# DEBUG:my_logger:Logging line 6353
# DEBUG:my_logger:Logging line 6354
# DEBUG:my_logger:Logging line 6355
# DEBUG:my_logger:Logging line 6356
# DEBUG:my_logger:Logging line 6357
# DEBUG:my_logger:Logging line 6358
# DEBUG:my_logger:Logging line 6359
# DEBUG:my_logger:Logging line 6360
# DEBUG:my_logger:Logging line 6361
# DEBUG:my_logger:Logging line 6362
# DEBUG:my_logger:Logging line 6363
# DEBUG:my_logger:Logging line 6364
# DEBUG:my_logger:Logging line 6365
# DEBUG:my_logger:Logging line 6366
# DEBUG:my_logger:Logging line 6367
# DEBUG:my_logger:Logging line 6368
# DEBUG:my_logger:Logging line 6369
# DEBUG:my_logger:Logging line 6370
# DEBUG:my_logger:Logging line 6371
# DEBUG:my_logger:Logging line 6372
# DEBUG:my_logger:Logging line 6373
# DEBUG:my_logger:Logging line 6374
# DEBUG:my_logger:Logging line 6375
# DEBUG:my_logger:Logging line 6376
# DEBUG:my_logger:Logging line 6377
# DEBUG:my_logger:Logging line 6378
# DEBUG:my_logger:Logging line 6379
# DEBUG:my_logger:Logging line 6380
# DEBUG:my_logger:Logging line 6381
# DEBUG:my_logger:Logging line 6382
# DEBUG:my_logger:Logging line 6383
# DEBUG:my_logger:Logging line 6384
# DEBUG:my_logger:Logging line 6385
# DEBUG:my_logger:Logging line 6386
# DEBUG:my_logger:Logging line 6387
# DEBUG:my_logger:Logging line 6388
# DEBUG:my_logger:Logging line 6389
# DEBUG:my_logger:Logging line 6390
# DEBUG:my_logger:Logging line 6391
# DEBUG:my_logger:Logging line 6392
# DEBUG:my_logger:Logging line 6393
# DEBUG:my_logger:Logging line 6394
# DEBUG:my_logger:Logging line 6395
# DEBUG:my_logger:Logging line 6396
# DEBUG:my_logger:Logging line 6397
# DEBUG:my_logger:Logging line 6398
# DEBUG:my_logger:Logging line 6399
# DEBUG:my_logger:Logging line 6400
# DEBUG:my_logger:Logging line 6401
# DEBUG:my_logger:Logging line 6402
# DEBUG:my_logger:Logging line 6403
# DEBUG:my_logger:Logging line 6404
# DEBUG:my_logger:Logging line 6405
# DEBUG:my_logger:Logging line 6406
# DEBUG:my_logger:Logging line 6407
# DEBUG:my_logger:Logging line 6408
# DEBUG:my_logger:Logging line 6409
# ...
# DEBUG:my_logger:Logging line 9530
# DEBUG:my_logger:Logging line 9531
# DEBUG:my_logger:Logging line 9532
# DEBUG:my_logger:Logging line 9533
# DEBUG:my_logger:Logging line 9534
# DEBUG:my_logger:Logging line 9535
# DEBUG:my_logger:Logging line 9536
# DEBUG:my_logger:Logging line 9537
# DEBUG:my_logger:Logging line 9538
# DEBUG:my_logger:Logging line 9539
# DEBUG:my_logger:Logging line 9540
# DEBUG:my_logger:Logging line 9541
# DEBUG:my_logger:Logging line 9542
# DEBUG:my_logger:Logging line 9543
# DEBUG:my_logger:Logging line 9544
# DEBUG:my_logger:Logging line 9545
# DEBUG:my_logger:Logging line 9546
# DEBUG:my_logger:Logging line 9547
# DEBUG:my_logger:Logging line 9548
# DEBUG:my_logger:Logging line 9549
# DEBUG:my_logger:Logging line 9550
# DEBUG:my_logger:Logging line 9551
# DEBUG:my_logger:Logging line 9552
# DEBUG:my_logger:Logging line 9553
# DEBUG:my_logger:Logging line 9554
# DEBUG:my_logger:Logging line 9555
# DEBUG:my_logger:Logging line 9556
# DEBUG:my_logger:Logging line 9557
# DEBUG:my_logger:Logging line 9558
# DEBUG:my_logger:Logging line 9559
# DEBUG:my_logger:Logging line 9560
# DEBUG:my_logger:Logging line 9561
# DEBUG:my_logger:Logging line 9562
# DEBUG:my_logger:Logging line 9563
# DEBUG:my_logger:Logging line 9564
# DEBUG:my_logger:Logging line 9565
# DEBUG:my_logger:Logging line 9566
# DEBUG:my_logger:Logging line 9567
# DEBUG:my_logger:Logging line 9568
# DEBUG:my_logger:Logging line 9569
# DEBUG:my_logger:Logging line 9570
# DEBUG:my_logger:Logging line 9571
# DEBUG:my_logger:Logging line 9572
# DEBUG:my_logger:Logging line 9573
# DEBUG:my_logger:Logging line 9574
# DEBUG:my_logger:Logging line 9575
# DEBUG:my_logger:Logging line 9576
# DEBUG:my_logger:Logging line 9577
# DEBUG:my_logger:Logging line 9578
# DEBUG:my_logger:Logging line 9579
# DEBUG:my_logger:Logging line 9580
# DEBUG:my_logger:Logging line 9581
# DEBUG:my_logger:Logging line 9582
# DEBUG:my_logger:Logging line 9583
# DEBUG:my_logger:Logging line 9584
# DEBUG:my_logger:Logging line 9585
# DEBUG:my_logger:Logging line 9586
# DEBUG:my_logger:Logging line 9587
# DEBUG:my_logger:Logging line 9588
# DEBUG:my_logger:Logging line 9589
# DEBUG:my_logger:Logging line 9590
# DEBUG:my_logger:Logging line 9591
# DEBUG:my_logger:Logging line 9592
# DEBUG:my_logger:Logging line 9593
# DEBUG:my_logger:Logging line 9594
# DEBUG:my_logger:Logging line 9595
# DEBUG:my_logger:Logging line 9596
# DEBUG:my_logger:Logging line 9597
# DEBUG:my_logger:Logging line 9598
# DEBUG:my_logger:Logging line 9599
# DEBUG:my_logger:Logging line 9600
# DEBUG:my_logger:Logging line 9601
# DEBUG:my_logger:Logging line 9602
# DEBUG:my_logger:Logging line 9603
# DEBUG:my_logger:Logging line 9604
# DEBUG:my_logger:Logging line 9605
# DEBUG:my_logger:Logging line 9606
# DEBUG:my_logger:Logging line 9607
# DEBUG:my_logger:Logging line 9608
# DEBUG:my_logger:Logging line 9609
# DEBUG:my_logger:Logging line 9610
# DEBUG:my_logger:Logging line 9611
# DEBUG:my_logger:Logging line 9612
# DEBUG:my_logger:Logging line 9613
# DEBUG:my_logger:Logging line 9614
# DEBUG:my_logger:Logging line 9615
# DEBUG:my_logger:Logging line 9616
# DEBUG:my_logger:Logging line 9617
# DEBUG:my_logger:Logging line 9618
# DEBUG:my_logger:Logging line 9619
# DEBUG:my_logger:Logging line 9620
# DEBUG:my_logger:Logging line 9621
# DEBUG:my_logger:Logging line 9622
# DEBUG:my_logger:Logging line 9623
# DEBUG:my_logger:Logging line 9624
# DEBUG:my_logger:Logging line 9625
# DEBUG:my_logger:Logging line 9626
# DEBUG:my_logger:Logging line 9627
# DEBUG:my_logger:Logging line 9628
# DEBUG:my_logger:Logging line 9629
# DEBUG:my_logger:Logging line 9630
# DEBUG:my_logger:Logging line 9631
# DEBUG:my_logger:Logging line 9632
# DEBUG:my_logger:Logging line 9633
# DEBUG:my_logger:Logging line 9634
# DEBUG:my_logger:Logging line 9635
# DEBUG:my_logger:Logging line 9636
# DEBUG:my_logger:Logging line 9637
# DEBUG:my_logger:Logging line 9638
# DEBUG:my_logger:Logging line 9639
# DEBUG:my_logger:Logging line 9640
# DEBUG:my_logger:Logging line 9641
# DEBUG:my_logger:Logging line 9642
# DEBUG:my_logger:Logging line 9643
# DEBUG:my_logger:Logging line 9644
# DEBUG:my_logger:Logging line 9645
# DEBUG:my_logger:Logging line 9646
# DEBUG:my_logger:Logging line 9647
# DEBUG:my_logger:Logging line 9648
# DEBUG:my_logger:Logging line 9649
# DEBUG:my_logger:Logging line 9650
# DEBUG:my_logger:Logging line 9651
# DEBUG:my_logger:Logging line 9652
# DEBUG:my_logger:Logging line 9653
# DEBUG:my_logger:Logging line 9654
# DEBUG:my_logger:Logging line 9655
# DEBUG:my_logger:Logging line 9656
# DEBUG:my_logger:Logging line 9657
# DEBUG:my_logger:Logging line 9658
# DEBUG:my_logger:Logging line 9659
# DEBUG:my_logger:Logging line 9660
# DEBUG:my_logger:Logging line 9661
# DEBUG:my_logger:Logging line 9662
# DEBUG:my_logger:Logging line 9663
# DEBUG:my_logger:Logging line 9664
# DEBUG:my_logger:Logging line 9665
# DEBUG:my_logger:Logging line 9666
# DEBUG:my_logger:Logging line 9667
# DEBUG:my_logger:Logging line 9668
# DEBUG:my_logger:Logging line 9669
# DEBUG:my_logger:Logging line 9670
# DEBUG:my_logger:Logging line 9671
# DEBUG:my_logger:Logging line 9672
# DEBUG:my_logger:Logging line 9673
# DEBUG:my_logger:Logging line 9674
# DEBUG:my_logger:Logging line 9675
# DEBUG:my_logger:Logging line 9676
# DEBUG:my_logger:Logging line 9677
# DEBUG:my_logger:Logging line 9678
# DEBUG:my_logger:Logging line 9679
# DEBUG:my_logger:Logging line 9680
# DEBUG:my_logger:Logging line 9681
# DEBUG:my_logger:Logging line 9682
# DEBUG:my_logger:Logging line 9683
# DEBUG:my_logger:Logging line 9684
# DEBUG:my_logger:Logging line 9685
# DEBUG:my_logger:Logging line 9686
# DEBUG:my_logger:Logging line 9687
# DEBUG:my_logger:Logging line 9688
# DEBUG:my_logger:Logging line 9689
# DEBUG:my_logger:Logging line 9690
# DEBUG:my_logger:Logging line 9691
# DEBUG:my_logger:Logging line 9692
# DEBUG:my_logger:Logging line 9693
# DEBUG:my_logger:Logging line 9694
# DEBUG:my_logger:Logging line 9695
# DEBUG:my_logger:Logging line 9696
# DEBUG:my_logger:Logging line 9697
# DEBUG:my_logger:Logging line 9698
# DEBUG:my_logger:Logging line 9699
# DEBUG:my_logger:Logging line 9700
# DEBUG:my_logger:Logging line 9701
# DEBUG:my_logger:Logging line 9702
# DEBUG:my_logger:Logging line 9703
# DEBUG:my_logger:Logging line 9704
# DEBUG:my_logger:Logging line 9705
# DEBUG:my_logger:Logging line 9706
# DEBUG:my_logger:Logging line 9707
# DEBUG:my_logger:Logging line 9708
# DEBUG:my_logger:Logging line 9709
# DEBUG:my_logger:Logging line 9710
# DEBUG:my_logger:Logging line 9711
# DEBUG:my_logger:Logging line 9712
# DEBUG:my_logger:Logging line 9713
# DEBUG:my_logger:Logging line 9714
# DEBUG:my_logger:Logging line 9715
# DEBUG:my_logger:Logging line 9716
# DEBUG:my_logger:Logging line 9717
# DEBUG:my_logger:Logging line 9718
# DEBUG:my_logger:Logging line 9719
# DEBUG:my_logger:Logging line 9720
# DEBUG:my_logger:Logging line 9721
# DEBUG:my_logger:Logging line 9722
# DEBUG:my_logger:Logging line 9723
# DEBUG:my_logger:Logging line 9724
# DEBUG:my_logger:Logging line 9725
# DEBUG:my_logger:Logging line 9726
# DEBUG:my_logger:Logging line 9727
# DEBUG:my_logger:Logging line 9728
# DEBUG:my_logger:Logging line 9729
# DEBUG:my_logger:Logging line 9730
# DEBUG:my_logger:Logging line 9731
# DEBUG:my_logger:Logging line 9732
# DEBUG:my_logger:Logging line 9733
# DEBUG:my_logger:Logging line 9734
# DEBUG:my_logger:Logging line 9735
# DEBUG:my_logger:Logging line 9736
# DEBUG:my_logger:Logging line 9737
# DEBUG:my_logger:Logging line 9738
# DEBUG:my_logger:Logging line 9739
# DEBUG:my_logger:Logging line 9740
# DEBUG:my_logger:Logging line 9741
# DEBUG:my_logger:Logging line 9742
# DEBUG:my_logger:Logging line 9743
# DEBUG:my_logger:Logging line 9744
# DEBUG:my_logger:Logging line 9745
# DEBUG:my_logger:Logging line 9746
# DEBUG:my_logger:Logging line 9747
# DEBUG:my_logger:Logging line 9748
# DEBUG:my_logger:Logging line 9749
# DEBUG:my_logger:Logging line 9750
# DEBUG:my_logger:Logging line 9751
# DEBUG:my_logger:Logging line 9752
# DEBUG:my_logger:Logging line 9753
# DEBUG:my_logger:Logging line 9754
# DEBUG:my_logger:Logging line 9755
# DEBUG:my_logger:Logging line 9756
# DEBUG:my_logger:Logging line 9757
# DEBUG:my_logger:Logging line 9758
# DEBUG:my_logger:Logging line 9759
# DEBUG:my_logger:Logging line 9760
# DEBUG:my_logger:Logging line 9761
# DEBUG:my_logger:Logging line 9762
# DEBUG:my_logger:Logging line 9763
# DEBUG:my_logger:Logging line 9764
# DEBUG:my_logger:Logging line 9765
# DEBUG:my_logger:Logging line 9766
# DEBUG:my_logger:Logging line 9767
# DEBUG:my_logger:Logging line 9768
# DEBUG:my_logger:Logging line 9769
# DEBUG:my_logger:Logging line 9770
# DEBUG:my_logger:Logging line 9771
# DEBUG:my_logger:Logging line 9772
# DEBUG:my_logger:Logging line 9773
# DEBUG:my_logger:Logging line 9774
# DEBUG:my_logger:Logging line 9775
# DEBUG:my_logger:Logging line 9776
# DEBUG:my_logger:Logging line 9777
# DEBUG:my_logger:Logging line 9778
# DEBUG:my_logger:Logging line 9779
# DEBUG:my_logger:Logging line 9780
# DEBUG:my_logger:Logging line 9781
# DEBUG:my_logger:Logging line 9782
# DEBUG:my_logger:Logging line 9783
# DEBUG:my_logger:Logging line 9784
# DEBUG:my_logger:Logging line 9785
# DEBUG:my_logger:Logging line 9786
# DEBUG:my_logger:Logging line 9787
# DEBUG:my_logger:Logging line 9788
# DEBUG:my_logger:Logging line 9789
# DEBUG:my_logger:Logging line 9790
# DEBUG:my_logger:Logging line 9791
# DEBUG:my_logger:Logging line 9792
# DEBUG:my_logger:Logging line 9793
# DEBUG:my_logger:Logging line 9794
# DEBUG:my_logger:Logging line 9795
# DEBUG:my_logger:Logging line 9796
# DEBUG:my_logger:Logging line 9797
# DEBUG:my_logger:Logging line 9798
# DEBUG:my_logger:Logging line 9799
# DEBUG:my_logger:Logging line 9800
# DEBUG:my_logger:Logging line 9801
# DEBUG:my_logger:Logging line 9802
# DEBUG:my_logger:Logging line 9803
# DEBUG:my_logger:Logging line 9804
# DEBUG:my_logger:Logging line 9805
# DEBUG:my_logger:Logging line 9806
# DEBUG:my_logger:Logging line 9807
# DEBUG:my_logger:Logging line 9808
# DEBUG:my_logger:Logging line 9809
# DEBUG:my_logger:Logging line 9810
# DEBUG:my_logger:Logging line 9811
# DEBUG:my_logger:Logging line 9812
# DEBUG:my_logger:Logging line 9813
# DEBUG:my_logger:Logging line 9814
# DEBUG:my_logger:Logging line 9815
# DEBUG:my_logger:Logging line 9816
# DEBUG:my_logger:Logging line 9817
# DEBUG:my_logger:Logging line 9818
# DEBUG:my_logger:Logging line 9819
# DEBUG:my_logger:Logging line 9820
# DEBUG:my_logger:Logging line 9821
# DEBUG:my_logger:Logging line 9822
# DEBUG:my_logger:Logging line 9823
# DEBUG:my_logger:Logging line 9824
# DEBUG:my_logger:Logging line 9825
# DEBUG:my_logger:Logging line 9826
# DEBUG:my_logger:Logging line 9827
# DEBUG:my_logger:Logging line 9828
# DEBUG:my_logger:Logging line 9829
# DEBUG:my_logger:Logging line 9830
# DEBUG:my_logger:Logging line 9831
# DEBUG:my_logger:Logging line 9832
# DEBUG:my_logger:Logging line 9833
# DEBUG:my_logger:Logging line 9834
# DEBUG:my_logger:Logging line 9835
# DEBUG:my_logger:Logging line 9836
# DEBUG:my_logger:Logging line 9837
# DEBUG:my_logger:Logging line 9838
# DEBUG:my_logger:Logging line 9839
# DEBUG:my_logger:Logging line 9840
# DEBUG:my_logger:Logging line 9841
# DEBUG:my_logger:Logging line 9842
# DEBUG:my_logger:Logging line 9843
# DEBUG:my_logger:Logging line 9844
# DEBUG:my_logger:Logging line 9845
# DEBUG:my_logger:Logging line 9846
# DEBUG:my_logger:Logging line 9847
# DEBUG:my_logger:Logging line 9848
# DEBUG:my_logger:Logging line 9849
# DEBUG:my_logger:Logging line 9850
# DEBUG:my_logger:Logging line 9851
# DEBUG:my_logger:Logging line 9852
# DEBUG:my_logger:Logging line 9853
# DEBUG:my_logger:Logging line 9854
# DEBUG:my_logger:Logging line 9855
# DEBUG:my_logger:Logging line 9856
# DEBUG:my_logger:Logging line 9857
# DEBUG:my_logger:Logging line 9858
# DEBUG:my_logger:Logging line 9859
# DEBUG:my_logger:Logging line 9860
# DEBUG:my_logger:Logging line 9861
# DEBUG:my_logger:Logging line 9862
# DEBUG:my_logger:Logging line 9863
# DEBUG:my_logger:Logging line 9864
# DEBUG:my_logger:Logging line 9865
# DEBUG:my_logger:Logging line 9866
# DEBUG:my_logger:Logging line 9867
# DEBUG:my_logger:Logging line 9868
# DEBUG:my_logger:Logging line 9869
# DEBUG:my_logger:Logging line 9870
# DEBUG:my_logger:Logging line 9871
# DEBUG:my_logger:Logging line 9872
# DEBUG:my_logger:Logging line 9873
# DEBUG:my_logger:Logging line 9874
# DEBUG:my_logger:Logging line 9875
# DEBUG:my_logger:Logging line 9876
# DEBUG:my_logger:Logging line 9877
# DEBUG:my_logger:Logging line 9878
# DEBUG:my_logger:Logging line 9879
# DEBUG:my_logger:Logging line 9880
# DEBUG:my_logger:Logging line 9881
# DEBUG:my_logger:Logging line 9882
# DEBUG:my_logger:Logging line 9883
# DEBUG:my_logger:Logging line 9884
# DEBUG:my_logger:Logging line 9885
# DEBUG:my_logger:Logging line 9886
# DEBUG:my_logger:Logging line 9887
# DEBUG:my_logger:Logging line 9888
# DEBUG:my_logger:Logging line 9889
# DEBUG:my_logger:Logging line 9890
# DEBUG:my_logger:Logging line 9891
# DEBUG:my_logger:Logging line 9892
# DEBUG:my_logger:Logging line 9893
# DEBUG:my_logger:Logging line 9894
# DEBUG:my_logger:Logging line 9895
# DEBUG:my_logger:Logging line 9896
# DEBUG:my_logger:Logging line 9897
# DEBUG:my_logger:Logging line 9898
# DEBUG:my_logger:Logging line 9899
# DEBUG:my_logger:Logging line 9900
# DEBUG:my_logger:Logging line 9901
# DEBUG:my_logger:Logging line 9902
# DEBUG:my_logger:Logging line 9903
# DEBUG:my_logger:Logging line 9904
# DEBUG:my_logger:Logging line 9905
# DEBUG:my_logger:Logging line 9906
# DEBUG:my_logger:Logging line 9907
# DEBUG:my_logger:Logging line 9908
# DEBUG:my_logger:Logging line 9909
# DEBUG:my_logger:Logging line 9910
# DEBUG:my_logger:Logging line 9911
# DEBUG:my_logger:Logging line 9912
# DEBUG:my_logger:Logging line 9913
# DEBUG:my_logger:Logging line 9914
# DEBUG:my_logger:Logging line 9915
# DEBUG:my_logger:Logging line 9916
# DEBUG:my_logger:Logging line 9917
# DEBUG:my_logger:Logging line 9918
# DEBUG:my_logger:Logging line 9919
# DEBUG:my_logger:Logging line 9920
# DEBUG:my_logger:Logging line 9921
# DEBUG:my_logger:Logging line 9922
# DEBUG:my_logger:Logging line 9923
# DEBUG:my_logger:Logging line 9924
# DEBUG:my_logger:Logging line 9925
# DEBUG:my_logger:Logging line 9926
# DEBUG:my_logger:Logging line 9927
# DEBUG:my_logger:Logging line 9928
# DEBUG:my_logger:Logging line 9929
# DEBUG:my_logger:Logging line 9930
# DEBUG:my_logger:Logging line 9931
# DEBUG:my_logger:Logging line 9932
# DEBUG:my_logger:Logging line 9933
# DEBUG:my_logger:Logging line 9934
# DEBUG:my_logger:Logging line 9935
# DEBUG:my_logger:Logging line 9936
# DEBUG:my_logger:Logging line 9937
# DEBUG:my_logger:Logging line 9938
# DEBUG:my_logger:Logging line 9939
# DEBUG:my_logger:Logging line 9940
# DEBUG:my_logger:Logging line 9941
# DEBUG:my_logger:Logging line 9942
# DEBUG:my_logger:Logging line 9943
# DEBUG:my_logger:Logging line 9944
# DEBUG:my_logger:Logging line 9945
# DEBUG:my_logger:Logging line 9946
# DEBUG:my_logger:Logging line 9947
# DEBUG:my_logger:Logging line 9948
# DEBUG:my_logger:Logging line 9949
# DEBUG:my_logger:Logging line 9950
# DEBUG:my_logger:Logging line 9951
# DEBUG:my_logger:Logging line 9952
# DEBUG:my_logger:Logging line 9953
# DEBUG:my_logger:Logging line 9954
# DEBUG:my_logger:Logging line 9955
# DEBUG:my_logger:Logging line 9956
# DEBUG:my_logger:Logging line 9957
# DEBUG:my_logger:Logging line 9958
# DEBUG:my_logger:Logging line 9959
# DEBUG:my_logger:Logging line 9960
# DEBUG:my_logger:Logging line 9961
# DEBUG:my_logger:Logging line 9962
# DEBUG:my_logger:Logging line 9963
# DEBUG:my_logger:Logging line 9964
# DEBUG:my_logger:Logging line 9965
# DEBUG:my_logger:Logging line 9966
# DEBUG:my_logger:Logging line 9967
# DEBUG:my_logger:Logging line 9968
# DEBUG:my_logger:Logging line 9969
# DEBUG:my_logger:Logging line 9970
# DEBUG:my_logger:Logging line 9971
# DEBUG:my_logger:Logging line 9972
# DEBUG:my_logger:Logging line 9973
# DEBUG:my_logger:Logging line 9974
# DEBUG:my_logger:Logging line 9975
# DEBUG:my_logger:Logging line 9976
# DEBUG:my_logger:Logging line 9977
# DEBUG:my_logger:Logging line 9978
# DEBUG:my_logger:Logging line 9979
# DEBUG:my_logger:Logging line 9980
# DEBUG:my_logger:Logging line 9981
# DEBUG:my_logger:Logging line 9982
# DEBUG:my_logger:Logging line 9983
# DEBUG:my_logger:Logging line 9984
# DEBUG:my_logger:Logging line 9985
# DEBUG:my_logger:Logging line 9986
# DEBUG:my_logger:Logging line 9987
# DEBUG:my_logger:Logging line 9988
# DEBUG:my_logger:Logging line 9989
# DEBUG:my_logger:Logging line 9990
# DEBUG:my_logger:Logging line 9991
# DEBUG:my_logger:Logging line 9992
# DEBUG:my_logger:Logging line 9993
# DEBUG:my_logger:Logging line 9994
# DEBUG:my_logger:Logging line 9995
# DEBUG:my_logger:Logging line 9996
# DEBUG:my_logger:Logging line 9997
# DEBUG:my_logger:Logging line 9998
# DEBUG:my_logger:Logging line 9999

# %% [markdown]
# QUES 19 -  Write a program that handles both IndexError and KeyError using a try-except block

# %%
def access_elements():
    sample_list = [10, 20, 30]
    sample_dict = {'a': 1, 'b': 2}

    try:
        # Attempt to access an index that may not exist
        print("Accessing list element at index 5:")
        print(sample_list[5])  # This will raise IndexError

        # Attempt to access a key that may not exist
        print("Accessing dictionary value for key 'c':")
        print(sample_dict['c'])  # This will raise KeyError

    except IndexError:
        print("Caught an IndexError: List index is out of range.")
    except KeyError:
        print("Caught a KeyError: Key does not exist in the dictionary.")

if __name__ == "__main__":
    access_elements()
# Out:
# Accessing list element at index 5:
# Caught an IndexError: List index is out of range.

# %% [markdown]
# QUES 20 -How would you open a file and read its contents using a context manager in Python

# %%
filename = "example.txt"

with open(filename, 'r') as file:
    content = file.read()

print(content)
# Out:
# This is line 1
# This is line 2
# This is line 3
# This is a new line.

# %% [markdown]
# QUES 21 - F Write a Python program that reads a file and prints the number of occurrences of a specific word

# %%
def count_word_occurrences(filename, word):
    try:
        with open(filename, 'r') as file:
            content = file.read().lower()  # Read and convert to lowercase
        word = word.lower()

        # Count occurrences of the word (as a whole word)
        words = content.split()
        count = words.count(word)

        print(f"The word '{word}' occurred {count} times in '{filename}'.")
    except FileNotFoundError:
        print(f"Error: The file '{filename}' does not exist.")
    except IOError as e:
        print(f"An error occurred while reading the file: {e}")

# Example usage
filename = input("Enter the file name: ")
word = input("Enter the word to count: ")
count_word_occurrences(filename, word)
# Out:
# Enter the file name: GHH
# Enter the word to count: 7
# Error: The file 'GHH' does not exist.

# %% [markdown]
# QUES 22 - How can you check if a file is empty before attempting to read its contents

# %%
import os

filename = "example.txt"

if os.path.exists(filename):
    if os.path.getsize(filename) > 0:
        with open(filename, 'r') as file:
            content = file.read()
        print("File content:")
        print(content)
    else:
        print("The file is empty.")
else:
    print(f"The file '{filename}' does not exist.")
# Out:
# File content:
# This is line 1
# This is line 2
# This is line 3
# This is a new line.

# %% [markdown]
# QUES 23 -  Write a Python program that writes to a log file when an error occurs during file handling.

# %%
import logging

# Setup basic logging configuration
logging.basicConfig(
    filename='error.log',
    level=logging.ERROR,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

def read_file(filename):
    try:
        with open(filename, 'r') as file:
            content = file.read()
            print("File content:")
            print(content)
    except Exception as e:
        logging.error(f"Error occurred while handling the file '{filename}': {e}")
        print(f"An error occurred. Check 'error.log' for details.")

# Example usage
filename = input("Enter the filename to read: ")
read_file(filename)
# Out:
# Enter the filename to read: r
# ERROR:root:Error occurred while handling the file 'r': [Errno 2] No such file or directory: 'r'
# An error occurred. Check 'error.log' for details.
